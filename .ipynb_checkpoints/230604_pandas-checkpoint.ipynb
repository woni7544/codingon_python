# %%
#Series 배열 만들기

# %%
import pandas as pd
a_series = pd.Series([143,150,157,160], index = ['2018','2019','2020','2021'])
print(a_series)
print(a_series['2018'])
# Out:
# 2018    143
# 2019    150
# 2020    157
# 2021    160
# dtype: int64
# 143

# %%
#DataFrame 만들기

# %%
index = ['2018', '2019','2020','2021']
yeonghee = pd.Series([143,150,157,160], index = index)
cheolsu = pd.Series([166,172,175,180], index = index)

growth = pd.DataFrame({'영희' : yeonghee,
                       '철수' : cheolsu})
growth
# Out:
#        영희   철수
# 2018  143  166
# 2019  150  172
# 2020  157  175
# 2021  160  180

# %%
df = pd.DataFrame({'철수' : [70, 80, 90],
                   '영희' : [77, 74, 100]})
df
# Out:
#    철수   영희
# 0  70   77
# 1  80   74
# 2  90  100

# %%
print(growth.dtypes)
growth_float = growth.astype('float')
print(growth.astype('float'))
# Out:
# 영희    int64
# 철수    int64
# dtype: object
#          영희     철수
# 2018  143.0  166.0
# 2019  150.0  172.0
# 2020  157.0  175.0
# 2021  160.0  180.0

# %%
wine = pd.read_csv('winemag-data-130k-v2.csv', index_col = 0)
wine
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
wine.shape
# Out:
# (129971, 13)

# %%
pd.set_option("display.max_rows", 5) #행 수를 5줄로 제한
wine
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
#Exercise 'Creating, Reading and Writing'

# %%
import pandas as pd
pd.set_option('display.max_rows', 5)
print("Setup complete.")
# Out:
# Setup complete.

# %%
#1
fruits = pd.DataFrame({'Apples' : [30],
                       'Bananas' : [21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
#2
index = ['2017 Sales', '2018 Sales']
fruit_sales = pd.DataFrame({'Apples'  : [35,41],
                           'Bananas' : [21,34]}, index = index)
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
#3
index = ['Flour','Milk','Eggs','Spam']
ingredients = ['4 cups', '1 cup', '2 large', '1 can']
dinner = pd.Series(ingredients, index = index, name = 'Dinner')
dinner
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
#4
reviews = pd.read_csv('winemag-data-130k-v2.csv', index_col = 0)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
#실습5
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
animals.to_csv("cows_and_goats.csv")

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
#인덱싱

# %%
reviews.iloc[:3,0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
#Location

# %%
reviews.loc[0,'country']
# Out:
# 'Italy'

# %%
reviews.loc[3,'designation']
# Out:
# 'Reserve Late Harvest'

# %%
#title을 index로 지정하기

# %%
reviews.set_index("title")
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %%
#country를 index로 지정하기

# %%
reviews.set_index("country")
# Out:
#                                                 description  \
# country
# Italy     Aromas include tropical fruit, broom, brimston...
# Portugal  This is ripe and fruity, a wine that is smooth...
# ...                                                     ...
# France    A dry style of Pinot Gris, this is crisp with ...
# France    Big, rich and off-dry, this is powered by inte...
#
#                             designation  points  price           province  \
# country
# Italy                      Vulkà Bianco      87    NaN  Sicily & Sardinia
# Portugal                       Avidagos      87   15.0              Douro
# ...                                 ...     ...    ...                ...
# France                              NaN      90   32.0             Alsace
# France    Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#          region_1 region_2    taster_name taster_twitter_handle  \
# country
# ...

# %%
reviews.loc[(reviews.country == 'Portugal') & 
            (reviews.points >= 95)]
# Out:
#          country                                        description  \
# 8862    Portugal  The estate is owned by the Olazabal family, de...
# 8881    Portugal  Always impressive, this wine is structured and...
# ...          ...                                                ...
# 122564  Portugal  Taylor Fladgate's vintage Ports are always amo...
# 122568  Portugal  A classic Fonseca, rich and powerful, with jus...
#
#                designation  points  price province region_1 region_2  \
# 8862                   NaN      95  100.0    Douro      NaN      NaN
# 8881    Vinha da Francisca      95  100.0    Douro      NaN      NaN
# ...                    ...     ...    ...      ...      ...      ...
# 122564             Vintage      96   99.0     Port      NaN      NaN
# 122568             Vintage      95   99.0     Port      NaN      NaN
#
#        taster_name taster_twitter_handle  \
# 8862    Roger Voss            @vossroger
# 8881    Roger Voss            @vossroger
# ...

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
#             ...
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
#Exercise 'Indexing, Selecting & Assigning'

# %%
#1
desc = reviews.description

# %%
#2
first_description = reviews.description[0]

# %%
#3
first_row = reviews.iloc[0,:]

# %%
#4
first_descriptions = reviews.description[:10]

# %%
#5
a = [1,2,3,5,8]
sample_reviews = reviews.loc[a]

# %%
#6
cols = ['country','province','region_1','region_2']
a = [0,1,10,100]
df = reviews.loc[a,cols]

# %%
#7
cols = ['country','variety']
df = reviews.loc[:99,cols]

# %%
df
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# ..       ...                       ...
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
#8
italian_wines = reviews.loc[reviews.country == 'Italy']
italian_wines
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
#9
top_oceania_wines = reviews.loc[(reviews.country.isin(['Australia','New Zealand'])) &
                                             (reviews.points >= 95)]
